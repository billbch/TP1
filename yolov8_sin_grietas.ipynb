# %% [markdown]
# #sin Grietas yolov8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

archivo_zip = "/content/drive/MyDrive/data/dataset.zip"  # Ruta completa del archivo ZIP
directorio_destino = "/content/"  # Ruta completa del directorio de destino

with zipfile.ZipFile(archivo_zip, 'r') as zip_ref:
    zip_ref.extractall(directorio_destino)

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.4/78.2 GB disk)

# %%
# !yolo train model=yolov8n.pt data=/content/custom.yaml epochs=215 imgsz=720
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 80.1MB/s]
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Validate YOLOv8n on COCO128 val
# !yolo val model=best.pt data=custom.yaml iou=0.5 imgsz=720
# Out:
# WARNING ⚠️ imgsz=[720] must be multiple of max stride 32, updating to [736]
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
# val: Scanning /content/dataset/labels/val.cache... 365 images, 129 backgrounds, 0 corrupt: 100% 494/494 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:15<00:00,  1.95it/s]
#                    all        494        926      0.978      0.958      0.986      0.697
#                  Hueco        494        627      0.966      0.946       0.98      0.667
#             HuecoGrave        494        299       0.99       0.97      0.992      0.727
# Speed: 2.6ms preprocess, 5.7ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to runs/detect/val3
