# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

archivo_zip = "/content/drive/MyDrive/data/dataset.zip"  # Ruta completa del archivo ZIP
directorio_destino = "/content/"  # Ruta completa del directorio de destino

with zipfile.ZipFile(archivo_zip, 'r') as zip_ref:
    zip_ref.extractall(directorio_destino)

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.4/78.2 GB disk)

# %%
# !yolo train model=yolov8n.pt data=/content/custom.yaml epochs=350 imgsz=720
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 64.5MB/s]
# Ultralytics YOLOv8.0.118 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Validate YOLOv8n on COCO128 val
# !yolo val model=best.pt data=custom.yaml iou=0.5 imgsz=720
# Out:
# WARNING ⚠️ imgsz=[720] must be multiple of max stride 32, updating to [736]
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
# val: Scanning /content/dataset/labels/val.cache... 461 images, 33 backgrounds, 0 corrupt: 100% 494/494 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 31/31 [00:16<00:00,  1.93it/s]
#                    all        494       1320      0.953      0.902      0.958      0.625
#                  Hueco        494        728      0.935      0.878      0.942       0.56
#                 Grieta        494        307      0.938      0.896      0.944      0.627
#             HuecoGrave        494        285      0.985      0.933      0.989      0.689
# Speed: 1.8ms preprocess, 6.3ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to runs/detect/val8

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load an official model
model = YOLO('/content/best.pt')  # load a custom model

# Validate the model
metrics = model.val(iou=0.5, data='custom.yaml')  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
# val: Scanning /content/dataset/labels/val.cache... 461 images, 33 backgrounds, 0 corrupt: 100%|██████████| 494/494 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 31/31 [00:16<00:00,  1.84it/s]
#                    all        494       1320      0.953      0.902      0.958      0.625
#                  Hueco        494        728      0.935      0.878      0.942       0.56
#                 Grieta        494        307      0.938      0.896      0.944      0.627
#             HuecoGrave        494        285      0.985      0.933      0.989      0.689
# Speed: 3.0ms preprocess, 5.1ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to runs/detect/val7
# array([    0.55987,     0.62715,     0.68923])
